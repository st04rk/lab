# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

img=cv2.imread("car.jpg")

blur_image=cv2.GaussianBlur(img,(3,3),0)
kernel=np.array([[0,-1,0],[-1,5,-1],[0,-1,0]])

sharpen_image=cv2.filter2D(img,-1,kernel)
edges=cv2.Canny(image=blur_image,threshold1=100,threshold2=200)

plt.figure(figsize=(12,6))

plt.subplot(221)
plt.title("Original Image")
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.axis("off")

plt.subplot(222)
plt.title("Blurred Image")
plt.imshow(cv2.cvtColor(blur_image,cv2.COLOR_BGR2RGB))
plt.axis("off")

plt.subplot(223)
plt.title("Sharpened Image")
plt.imshow(cv2.cvtColor(sharpen_image,cv2.COLOR_BGR2RGB))
plt.axis("off")

plt.subplot(224)
plt.title("Edge of Image")
plt.imshow(cv2.cvtColor(edges,cv2.COLOR_BGR2RGB))
plt.axis("off")

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 27
#      25 plt.subplot(223)
#      26 plt.title("Sharpened Image")
# ---> 27 plt.imshow(cv2.cvtColor(sharpen_image,cv2.COLOR_BGR2RGB))
#      28 plt.axis("off")
#      30 plt.subplot(224)
#
# NameError: name 'sharpen_image' is not defined
